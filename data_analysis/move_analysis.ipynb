# %% [markdown]
# The following is analysis of US Census move-in data.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../data/move_by_state.csv')

# %%
df.head()
# Out:
#         State  Total Population  Moved Percent  Moved Total
# 0     Alabama           4849509            2.2       106689
# 1      Alaska            722063            4.7        33937
# 2     Arizona           7200620            3.5       252022
# 3    Arkansas           2989054            2.0        59781
# 4  California          39084048            1.2       469009

# %%
df["Moved Total"].hist()
# Out:
# <AxesSubplot:>

# %%
sorted_df = df.sort_values('Moved Total')

# %%
sorted_df
# Out:
#                    State  Total Population  Moved Percent  Moved Total
# 45               Vermont            617560            3.4        20997
# 41          South Dakota            872708            3.1        27054
# 50               Wyoming            572884            5.3        30363
# 1                 Alaska            722063            4.7        33937
# 39          Rhode Island           1050602            3.3        34670
# 19                 Maine           1331656            2.7        35955
# 34          North Dakota            750501            4.9        36775
# 7               Delaware            964817            3.9        37628
# 48         West Virginia           1773280            2.2        39012
# 26               Montana           1056994            3.9        41223
# 27              Nebraska           1910711            2.4        45857
# 29         New Hampshire           1350155            3.7        49956
# ...

# %% [markdown]
# To get an idea of which states were most desirable, I thought population change could be a good metric to use. In this case, I took the amount of people who moved in from another state, since places would likely be more desirable if they are attracting people from other parts of the United States. Geographically, there is a mix between areas like the northeast and the west coast with sunbelt states like Georgia and North Carolina.

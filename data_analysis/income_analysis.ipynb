# %%
The following is analysis of US Census income data.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../data/income_data_by_state.csv')

# %%
df.head()
# Out:
#   Geographic Area Name  Total Households  Median Income
# 0              Alabama           1897576          51734
# 1               Alaska            252199          75463
# 2              Arizona           2670441          62055
# 3             Arkansas           1163647          48952
# 4           California          13157873          80440

# %%
df['Median Income'].hist()
# Out:
# <AxesSubplot:>

# %%
sorted_df = df.sort_values('Median Income')

# %%
sorted_df
# Out:
#     Geographic Area Name  Total Households  Median Income
# 24           Mississippi           1100229          45792
# 48         West Virginia            728175          48850
# 3               Arkansas           1163647          48952
# 18             Louisiana           1741076          51073
# 0                Alabama           1897576          51734
# 31            New Mexico            793420          51945
# 17              Kentucky           1748732          52295
# 36              Oklahoma           1495151          54449
# 42             Tennessee           2654737          56071
# 40        South Carolina           1975915          56227
# 26               Montana            437651          57153
# 33        North Carolina           4046348          57341
# 25              Missouri           2458337          57409
# 14               Indiana           2597765          57603
# 35                  Ohio           4730340          58642
# ...

# %% [markdown]
# The states with higher median incomes tend to skew towards the northeast and the west coast, with Hawaii being the exception. Lower income states are concentrated in the south and the midwest.
